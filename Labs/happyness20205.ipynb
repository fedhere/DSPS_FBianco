# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/DSPS_FBianco/blob/main/Labs/happyness20205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pylab import plt
from missingno import matrix

# %%
happinessdf = pd.read_csv("https://raw.githubusercontent.com/fedhere/FDSFE_FBianco/refs/heads/main/data/happines.csv")

# %%
print("the numnber of rows and columns in the dataset is (rows,columns) {} there you have".format(happinessdf.shape))
# Out:
# the numnber of rows and columns in the dataset is (rows,columns) (160, 12) there you have

# %%
happinessdf.head()
# Out:
#        Country          Region  Happiness Score  Standard Error  \
# 0  Switzerland  Western Europe            7.587         0.03411
# 1      Iceland  Western Europe            7.561         0.04884
# 2      Denmark  Western Europe            7.527         0.03328
# 3       Norway  Western Europe            7.522         0.03880
# 4       Canada   North America            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 0                        0.41978     0.29678            2.51738  2015
# ...

# %%
happinessdf.tail()
# Out:
#      Country                           Region  Happiness Score  \
# 155    Syria  Middle East and Northern Africa            3.006
# 156  Burundi               Sub-Saharan Africa            2.905
# 157     Togo               Sub-Saharan Africa            2.839
# 158  Namibia                              NaN            4.639
# 159   Gambia                              NaN            4.516
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 155         0.05015                   0.66320  0.47489
# 156         0.08658                   0.01530  0.41587
# 157         0.06727                   0.20868  0.13995
# 158             NaN                   0.87900      NaN
# 159             NaN                   0.30800      NaN
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# ...

# %%
happinessdf.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       160.000000      158.000000                160.000000  158.000000
# mean          5.365756        0.047885                  0.842979    0.991046
# std           1.141280        0.017146                  0.402840    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.517750        0.037268                  0.539453    0.856823
# 50%           5.203000        0.043940                  0.901085    1.029510
# 75%           6.193250        0.052300                  1.155523    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                160.000000  160.000000                     160.000000
# mean                   0.628037    0.428151                       0.143023
# ...

# %%
happinessdf.isna()
# Out:
#      Country  Region  Happiness Score  Standard Error  \
# 0      False   False            False           False
# 1      False   False            False           False
# 2      False   False            False           False
# 3      False   False            False           False
# 4      False   False            False           False
# ..       ...     ...              ...             ...
# 155    False   False            False           False
# 156    False   False            False           False
# 157    False   False            False           False
# 158    False    True            False            True
# 159    False    True            False            True
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                       False   False                     False    False
# 1                       False   False                     False    False
# 2                       False   False                     False    False
# ...

# %%
plt.imshow(happinessdf.isna())

# %%
from missingno import matrix
matrix(happinessdf)
# Out:
# <Axes: >

# %%
happinessdf.isna().sum()
# Out:
# Country                          0
# Region                           2
# Happiness Score                  0
# Standard Error                   2
# Economy (GDP per Capita)         0
# Family                           2
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                2
# year                             0
# dtype: int64

# %%
meadian_hap = happinessdf["Happiness Score"].median()
print("the median happiness is {0:.2f}".format(meadian_hap))
# Out:
# the median happiness is 5.20

# %%
happinessdf[happinessdf["Happiness Score"] > meadian_hap]
# Out:
#         Country                           Region  Happiness Score  \
# 0   Switzerland                   Western Europe            7.587
# 1       Iceland                   Western Europe            7.561
# 2       Denmark                   Western Europe            7.527
# 3        Norway                   Western Europe            7.522
# 4        Canada                    North America            7.427
# ..          ...                              ...              ...
# 75       Turkey  Middle East and Northern Africa            5.332
# 76   Kyrgyzstan       Central and Eastern Europe            5.286
# 77      Nigeria               Sub-Saharan Africa            5.268
# 78       Bhutan                    Southern Asia            5.253
# 79   Azerbaijan       Central and Eastern Europe            5.212
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 0          0.03411                   1.39651  1.34951
# 1          0.04884                   1.30232  1.40223
# ...

# %%
mean_hap = happinessdf["Happiness Score"].mean()
print("the median happiness is {0:.2f}".format(mean_hap))
# Out:
# the median happiness is 5.37

# %%
happinessdf[happinessdf["Happiness Score"] > mean_hap]
# Out:
#          Country                      Region  Happiness Score  Standard Error  \
# 0    Switzerland              Western Europe            7.587         0.03411
# 1        Iceland              Western Europe            7.561         0.04884
# 2        Denmark              Western Europe            7.527         0.03328
# 3         Norway              Western Europe            7.522         0.03880
# 4         Canada               North America            7.427         0.03553
# ..           ...                         ...              ...             ...
# 69  Turkmenistan  Central and Eastern Europe            5.548         0.04175
# 70     Mauritius          Sub-Saharan Africa            5.477         0.07197
# 71     Hong Kong                Eastern Asia            5.474         0.05051
# 72       Estonia  Central and Eastern Europe            5.429         0.04013
# 73     Indonesia           Southeastern Asia            5.399         0.02596
#
# ...
