# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/DSPS_FBianco/blob/main/Labs/scattercontours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Designed by Federica Bianco:
#
# visualization homework
#
# improving plots
#
# 2019 version: DSPS UDel

# %%
import pylab as pl
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
# you will use astropy to make the contours-scatter plot
from astropy import constants as const
from astropy import units as u
pylab.style.use("https://raw.githubusercontent.com/fedhere/DSPS_FBianco/master/fbb.mplstyle")

# %% [markdown]
# # high density to contours examples

# %% [markdown]
# ## get data on  star data from kepler2 mission

# %%
url = "https://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/nph-nstedAPI"
url +="?table=k2targets&select=epic_number,k2_teff,k2_rad"
url +="&format=CSV"

# %%
df = pd.read_csv(url)
df.head()
# Out:
#    epic_number  k2_teff  k2_rad
# 0     60018365      NaN     NaN
# 1     60018369      NaN     NaN
# 2     60018371      NaN     NaN
# 3     60018372      NaN     NaN
# 4     60018374      NaN     NaN

# %% [markdown]
# ## Add a column for the star luminosity in Watts
# follow [this description](http://personal.psu.edu/mxe17/A010/lectures/lect19.html) Section 2

# %% [markdown]
# The luminosity of the star is $4 ~ \pi ~ r^2 ~\sigma~ T^4$
# with $\sigma$ Boltzmann constand, $T$ temperature, $r$ radius of the star.
#
# Note that the radius is given in sun radii, use ```const.R_sun``` to get the radius in natural units instead.

# %%
df['k2_L'] = 4 * np.pi * (df['k2_rad'] * const.R_sun)**2 * \
            const.sigma_sb * df['k2_teff']**4
#Adding a column for luminosity in (Watts)

# %% [markdown]
# ## Plot the HR diagram:

# %%
df.plot.scatter(x='k2_teff',y='k2_L', loglog=True, color='k', s=20, figsize=(9,9))
plt.xlim(40000,1000)
plt.xlabel(r'$T_{eff}$ (K)')
plt.ylabel('Luminosity (W)');

# %% [markdown]
# ## Plot the HR diagram using transparency to better the readability of the plot:

# %%
df.plot.scatter(..., alpha=...)
plt.xlim(40000, 1000)
plt.xlabel(r'$T_{eff}$ (K)')
plt.ylabel('Luminosity (W)');

# %% [markdown]
# ## AstroML version

# %%
# !pip install astroML
# Out:
# Collecting astroML
#   Downloading astroML-1.0.2.post1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.12/dist-packages (from astroML) (1.6.1)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.12/dist-packages (from astroML) (2.0.2)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.12/dist-packages (from astroML) (1.16.3)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.12/dist-packages (from astroML) (3.10.0)
# Requirement already satisfied: astropy>=3.0 in /usr/local/lib/python3.12/dist-packages (from astroML) (7.1.1)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.12/dist-packages (from astropy>=3.0->astroML) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.9.29.0.35.48 in /usr/local/lib/python3.12/dist-packages (from astropy>=3.0->astroML) (0.2025.11.3.0.38.37)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=3.0->astroML) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=3.0->astroML) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->astroML) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->astroML) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->astroML) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->astroML) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->astroML) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->astroML) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->astroML) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.18->astroML) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.18->astroML) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->astroML) (1.17.0)
# Downloading astroML-1.0.2.post1-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: astroML
# Successfully installed astroML-1.0.2.post1

# %%
from astroML import plotting
plotting.scatter_contour?
# Out:
# /usr/local/lib/python3.12/dist-packages/astroML/linear_model/linear_regression_errors.py:10: UserWarning: LinearRegressionwithErrors requires PyMC3 to be installed
#   warnings.warn('LinearRegressionwithErrors requires PyMC3 to be installed')

# %%
#rememnber that you are making a log-log plot
ax = plt.figure(figsize=(10,10)).add_subplot()
plotting.scatter_contour(...

# %%
ax = plt.figure(figsize=(10,10)).add_subplot()
plotting.scatter_contour(...

# %%
from astroML import plotting
#rememnber that you are making a log-log plot
ax = plt.figure(figsize=(10,10)).add_subplot()
plotting.scatter_contour(...)

plt.ylabel('log(Luminosity) (W)')
plt.xlabel(r'$log(T_{eff})$ (K)')
plt.xlim(4.5, 3.2)
plt.savefig("k2scatter_contour.png")

# %% [markdown]
# # by-hand version
#
# Here is how you would do this by hand.

# %%
H, xbins, ybins = np.histogram2d(np.log10(teff_na), np.log10(L_na), bins=(40, 40))
Hsort = np.sort(H.flatten())

# %%
extent = [xbins[0], xbins[-1], ybins[0], ybins[-1]]
ax = pl.figure(figsize=(10,10)).add_subplot(111)
levels = np.linspace(H.max()/15, H.max(), 5)
i_min = np.argmin(levels)
outline = ax.contour(H.T, levels[i_min:i_min + 1],
                         linewidths=0, extent=extent)

#contours = ax.contourf(H.T, levels, extent=extent, cmap='bone')
X = np.hstack([np.log10(teff_na)[:, None], np.log10(L_na)[:, None]])

if len(outline.allsegs[0]) > 0:
    outer_poly = outline.allsegs[0][0]
    try:
        # this works in newer matplotlib versions
        from matplotlib.path import Path
        points_inside = Path(outer_poly).contains_points(X)
    except:
        # this works in older matplotlib versions
        import matplotlib.nxutils as nx
        points_inside = nx.points_inside_poly(X, outer_poly)

    Xplot = X[~points_inside]
else:
    Xplot = X

points = ax.plot(Xplot[:, 0], Xplot[:, 1], '.', ms=10, alpha=0.05, c='k')
outline = ax.contour(H.T, levels[i_min:i_min + 1],
                         linewidths=0, extent=extent)
axc = contourf(H.T, extent=extent, levels=levels,
               linewidths=3, cmap='winter', alpha=0.7)

plt.xlim(4.5,3.2)
plt.ylabel('log(Luminosity) (W)')
plt.xlabel(r'$log(T_{eff})$ (K)');

# %%
#make a correlation matrix for the variables in the dataframe
