# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/DSPS_FBianco/blob/main/L08_ML_ClassificationAndRegressionTrees/higgsbosonSearch_solution2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
import json
import os
import pandas as pd
import seaborn as sns
import pylab as plt
from pprint import pprint
import numpy as np
from sklearn.model_selection import train_test_split
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import RandomizedSearchCV

# %%
#mount your google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Task 1 : data ingestion

# %% [markdown]
# - Download the Higgs boson data from Kaggle (programmatically within the notebook)
# see how I did it in the Titanic Trees notebook https://github.com/fedhere/DSPS_FBianco/blob/main/CodeDemos/titanictree.ipynb
#
# find the correct API link here https://www.kaggle.com/c/higgs-boson/data. The command is `!kaggle competitions download......` (you may need to agree to the terms of condition of the higgs boson challenge on the kaggle webpage)

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
#setting up the environment variables to log into kaggle
envs = json.load(open("kaggle/kaggle.json", "r"))
os.environ["KAGGLE_USERNAME"] = envs['username']
os.environ["KAGGLE_KEY"] = envs['key']

# %%
# !kaggle datasets list -s boson
# Out:
# ...
# ref                                                         title                                                 size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  ---------------------------------------------  -----------  --------------------------  -------------  ---------  ---------------
# ryanholbrook/higgs-boson                                    Higgs Boson                                     1100112219  2020-10-02 23:04:26.343000           1276         12  0.375
# omidbaghchehsaraei/identification-of-two-modes-of-z-boson   Z boson DataSet                                     627191  2023-02-15 15:11:35.243000            395         11  1
# knight079/higgsb                                            Higgs Boson Dataset                               59325616  2017-10-17 06:27:15.307000            901          7  0.4117647
# ...

# %%
cd dsps
# Out:
# /content/drive/.shortcut-targets-by-id/1-5t43D_9M7Er0dU3JODw0CQdOs9lb_Gy/dsps

# %%
# !mkdir higgsbosons
# Out:
# mkdir: cannot create directory ‘higgsbosons’: File exists

# %%
cd higgsbosons
# Out:
# /content/drive/.shortcut-targets-by-id/1-5t43D_9M7Er0dU3JODw0CQdOs9lb_Gy/dsps/higgsbosons

# %%
# !kaggle competitions download -c higgs-boson
# Out:
# higgs-boson.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip higgs-boson.zip
# Out:
# Archive:  higgs-boson.zip
# replace HiggsBosonCompetition_AMSMetric_rev1.py? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !unzip training.zip
# Out:
# Archive:  training.zip
# replace training.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
higgsdata = pd.read_csv("training.csv")
display(higgsdata)
# Out:
#         EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0        100000       138.470                       51.655        97.827
# 1        100001       160.937                       68.768       103.235
# 2        100002      -999.000                      162.172       125.953
# 3        100003       143.905                       81.417        80.943
# 4        100004       175.864                       16.915       134.805
# ...         ...           ...                          ...           ...
# 249995   349995      -999.000                       71.989        36.548
# 249996   349996      -999.000                       58.179        68.083
# 249997   349997       105.457                       60.526        75.839
# 249998   349998        94.951                       19.362        68.812
# 249999   349999      -999.000                       72.756        70.831
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# ...

# %% [markdown]
# At this point, it is important to look at the documentation to see _what_ we are acutally looking at! I know we are not particle physics experts, but we should understand the data as best as possible (within the time contraints) to avoid making naive mistakes

# %% [markdown]
# From the Kaggle challenge webpage https://www.kaggle.com/competitions/higgs-boson/data
#
# - all variables are floating point, except PRI_jet_num which is integer
# variables
# - prefixed with PRI (for PRImitives) are “raw” quantities about the bunch collision as measured by the detector.
# - variables prefixed with DER (for DERived) are quantities computed from the primitive features, which were selected by  the physicists of ATLAS
# - it can happen that for some entries some variables are meaningless or cannot be computed; in this case, their value is −999.0, which is outside the normal range of all variables

# %% [markdown]
# # Task 2: data exploration

# %%
higgsdata.head() #check the top of the file to better undersatnd the structure
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_num  PRI_jet_leading_pt  \
# ...

# %%
higgsdata.describe() #check the bottom of the file to ensure it is consistent throughout
# Out:
#              EventId   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  250000.000000  250000.000000                250000.000000
# mean   224999.500000     -49.023079                    49.239819
# std     72168.927986     406.345647                    35.344886
# min    100000.000000    -999.000000                     0.000000
# 25%    162499.750000      78.100750                    19.241000
# 50%    224999.500000     105.012000                    46.524000
# 75%    287499.250000     130.606250                    73.598000
# max    349999.000000    1192.026000                   690.075000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  250000.000000  250000.000000         250000.000000     250000.000000
# mean       81.181982      57.895962           -708.420675       -601.237051
# std        40.828691      63.655682            454.480565        657.972302
# ...

# %% [markdown]
# do everything else you need to explore the data: shape, presence of nan, visualizations (remember to subsample where needed, this is a huge file!)

# %%
original_shape = higgsdata.shape #what is the shape of the data?
print(f"the original shape of the data is {original_shape}: {np.prod(original_shape)} entries")
# Out:
# the original shape of the data is (250000, 33): 8250000 entries

# %%
_ = higgsdata.isna().sum().sum() #are there any NaN or invalid columns?
if _ == 0:
  print("there are no NaN values to take care of")
else:
  print(f"there are {_} NaN values")
# Out:
# there are no NaN values to take care of

# %%
sns.pairplot(higgsdata[::10_000]) # showing a correlation plot - subsampling significantly to save time

# %% [markdown]
# Figure 1: the pair plot shows distributions of each variable on the diagonal and correlation on the off diagonal elements. With these many variables this is not a useful visualization

# %% [markdown]
# Because there are so many variables, the pair plot is really hard to read (and to make! it takes forever even at this downsampling!). Let's instead just look at the distribution of each variable and at the correlation in a heatmap

# %%
correlation_matrix = higgsdata.select_dtypes(include='number').corr()
plt.imshow(correlation_matrix, cmap="RdBu", clim=(-1,1))
columns = higgsdata.select_dtypes(include='number').columns
plt.xticks(range(len(columns)), columns, rotation=90)
plt.yticks(range(len(columns)), columns);
plt.colorbar();

# %% [markdown]
# Figure 2: correlation matrix for the full Higgs boson dataset. A block structure indicates strong correlations among related variables. For example the jet properties  are strongly correlated

# %%
fig, axs = plt.subplots(5, int(higgsdata.shape[1]/5)+1, figsize=(20,10))
axs = axs.flatten()
for i,c in enumerate(higgsdata.columns):
  higgsdata[c].hist(ax=axs[i])
  axs[i].set_xlabel(c)
  axs[i].set_ylabel("counts")
for i in range(len(higgsdata.columns), len(axs)):
  axs[i].axis('off')
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# Figure 3: distribution of each variable in the dataset. We can see bell-shaped distributions (e.g. PRI_tau_eta), discrete number distributions (PRI_jet_number), what looks like uniform distributions (PRI_tau_phi for example) and also a large number of bimodal distribution with a significant peak at -1,000 (see also the data description! they told us this on the Kaggle website).

# %% [markdown]
# aha! there is something suspicious! First off: the first column is an index. We should remember to remove it in the analysis. But als, and more interestingly, there are several variables with spikes in their distribution at -999... those are missing values replaces with an (unlikely) numerical value. This is not a great idea - you should not do that as a data curator. Let's replace them with NaN

# %%
(higgsdata==-999).sum()
# Out:
# EventId                             0
# DER_mass_MMC                    38114
# DER_mass_transverse_met_lep         0
# DER_mass_vis                        0
# DER_pt_h                            0
# DER_deltaeta_jet_jet           177457
# DER_mass_jet_jet               177457
# DER_prodeta_jet_jet            177457
# DER_deltar_tau_lep                  0
# DER_pt_tot                          0
# DER_sum_pt                          0
# DER_pt_ratio_lep_tau                0
# DER_met_phi_centrality              0
# DER_lep_eta_centrality         177457
# PRI_tau_pt                          0
# PRI_tau_eta                         0
# PRI_tau_phi                         0
# PRI_lep_pt                          0
# PRI_lep_eta                         0
# PRI_lep_phi                         0
# PRI_met                             0
# PRI_met_phi                         0
# PRI_met_sumet                       0
# PRI_jet_num                         0
# PRI_jet_leading_pt              99913
# ...

# %%
higgsdata.replace(-999, np.nan, inplace=True)

# %%
higgsdata = higgsdata.dropna()

# %%
print(f"the new shape of the file is {higgsdata.shape})")
print(f"we removes {np.prod(original_shape) - np.prod(higgsdata.shape)} entries "
      f"or {-(np.prod(higgsdata.shape) - np.prod(original_shape)) / np.prod(original_shape) * 100}% of the data")
# Out:
# the new shape of the file is (68114, 33))
# we removes 6002238 entries or 72.7544% of the data

# %% [markdown]
# That is A LOT of data!! Procedurally, this is unlikely to be the best strategy. It will be fine for a homework assignment, but can you think of what other strategies you could use??
#
# For example, a Bayesian two-step analysis could set a prior on the nature of the detection based on the variable for whcih all values are available, and define tbe probability based on the value of the other columns _and_ the prior.

# %%
correlation_matrix = higgsdata.select_dtypes(include='number').corr()
plt.imshow(correlation_matrix, cmap="RdBu", clim=(-1,1))
columns = higgsdata.select_dtypes(include='number').columns
plt.xticks(range(len(columns)), columns, rotation=90)
plt.yticks(range(len(columns)), columns);
plt.colorbar();

# %% [markdown]
# Figure 4. The data cleaning significantly remove covariance in the data. At this point the correlation is weak for most pairs of variable with the notable exception of DER_deltaeta_jet_jet
# DER_mass_jet_jet
# DER_prodeta_jet_jet. This set of variables (starting with DER) is a set of values derived from the raw (PRI) data, so it makes sense that they may be correlated if they are transfomrations that use the same raw data with different mathematical formulations.

# %%
fig, axs = plt.subplots(5, int(higgsdata.shape[1]/5)+1, figsize=(20,10))
axs = axs.flatten()
for i,c in enumerate(higgsdata.columns):
  higgsdata[c].hist(ax=axs[i])
  axs[i].set_xlabel(c)
  axs[i].set_ylabel("counts")
for i in range(len(higgsdata.columns), len(axs)):
  axs[i].axis('off')
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# Figure 4: the majority of the distribution tht showed bimodality in Figure 3 now are no longer bimodal. A few mimodal distributions remain, but are expected to be bimodal in nature (PRI_jet_number). The majority of the distributions are significantly skewed, which woudl suggest a non-linear analysis (like a tree based analysis) is appropriate.

# %% [markdown]
# # Task 3: data preparation

# %% [markdown]
# - Read in the trainind data. Split the provided training data into a training and a test set.
# The last 2 columns are what you want to predict: "weight" and "label".
# Remove them from the input data and create a separate variable label and a separate variable weight, which will be your target variables for, respectively, classification and regression.

# %% [markdown]
#  you will use two target variables (you can read more about the data at https://higgsml.lal.in2p3.fr/files/2014/04/documentation_v1.8.pdf): find the corresponding columns of the DF and save them as labels and weights respectively

# %%
labels = higgsdata["Label"].values
weights = higgsdata["Weight"].values

# %%
labels # 's' stands for signal, 'b' for background. You want to find new particles, i.e. "signal"
# Out:
# array(['s', 'b', 's', ..., 's', 's', 'b'], dtype=object)

# %%
weights # the weight of the particle
# Out:
# array([0.00265331, 0.08341403, 0.00265331, ..., 0.01863612, 0.0015027 ,
#        0.06406078])

# %%
#is the dataset balanced?
np.unique(labels, return_counts=True)
# Out:
# (array(['b', 's'], dtype=object), array([36220, 31894]))

# %% [markdown]
# The dataset for classification is roughly balanced (no need for augmentation or rebalancing)

# %%
plt.hist(weights)
plt.xlabel("weight")
plt.ylabel("count");

# %% [markdown]
# The distribution of weight values is highly non linear. Performing this analysis in a proxy space, like the logarithm of the target variable, may be beneficial

# %% [markdown]
# This kaggle challenge has a separate dataset for testing, but we will not use it. We will use the "training.csv" file, but create your own train/test sets

# %%
#first the data for classification
#drop the target variables and the index from the training data
train_x, test_x, train_y, test_y = train_test_split(higgsdata.drop(["EventId", "Label", "Weight"],
                                                                   axis=1), labels, random_state=302) #remember to set the random state for reproducibilty!
train_x.shape, train_y.shape, test_x.shape, test_y.shape
# Out:
# ((51085, 30), (51085,), (17029, 30), (17029,))

# %%
#then the data for regression
train_regress_x, test_regress_x, train_regress_y, test_regress_y = train_test_split(higgsdata.drop(["EventId", "Label", "Weight"],
                                                                   axis=1), weights, random_state=302)
train_regress_x.shape, train_regress_y.shape, test_regress_x.shape, test_regress_y.shape
# Out:
# ((51085, 30), (51085,), (17029, 30), (17029,))

# %% [markdown]
# #Task 4: answer the question (you, not an AI...) why did I not ask you to scale the data like we did in the cluster models?

# %% [markdown]
# Because the tree models use each feature separately setting binary decisions for each one in a flow-chart type model, so the relative magnitude of a feature does not matter since the features are not combined mathematically or ever compared in the model

# %% [markdown]
# # Task 5: tree-based classifications
# Use a Random Forest and a Gradiend Boosted Tree Classifier model to predict the label of the particles. get the score of each model on both the training and test set, compare them training and test results and comment on the result for each model (adjust the hyperparameters if you need to)

# %%
# Look at parameters used by our current forest
rf = RandomForestClassifier(random_state = 0)
print('Parameters currently in use:\n')
pprint(rf.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# build the models

# %%
#set a modest max_depth to avoid overfitting. You should test what value is appropriate
rf = RandomForestClassifier(max_depth=3, random_state=302) #remember to set the random state for reproducibility!

# %%
gbt = GradientBoostingClassifier(max_depth=3, random_state=302)

# %% [markdown]
# fit the models to the data

# %%
rf.fit(train_x, train_y)
gbt.fit(train_x, train_y)
# Out:
# GradientBoostingClassifier(random_state=302)

# %% [markdown]
# # Task 6: model evaluation

# %% [markdown]
# calculate the  scores for the training and test sets and evaluate  overtraining etc

# %%
rf_train_score = rf.score(train_x, train_y)
rf_test_score = rf.score(test_x, test_y)

gbt_train_score = gbt.score(train_x, train_y)
gbt_test_score = gbt.score(test_x, test_y)

# %%
print(f"the RF scores on the training test is {rf_train_score:.2f}, on the test is {rf_test_score:.2f}")
if rf_train_score - rf_test_score < rf_train_score/10: #a somwehat arbitrary 10% threshold to worry about overfitting
  print("if this indicated NO overfitting")
else:
  print("we should worry about overfitting")
print(f"the GBT scores on the training test is {gbt_train_score:.2f}, on the test is {gbt_test_score:.2f}")
if gbt_train_score - gbt_test_score < gbt_train_score/10:
  print("if this indicated NO overfitting")
else:
  print("we should worry about overfitting")
# Out:
# the RF scores on the training test is 0.80, on the test is 0.80
# if this indicated NO overfitting
# the GBT scores on the training test is 0.85, on the test is 0.84
# if this indicated NO overfitting

# %% [markdown]
# **Comment** is your model performing well? is it .... overfitting?

# %% [markdown]
# The model prediction has an accuracy of 80%. Without context it is hard to say if this means it is performing well. The prediction is informed (i.e. better than a random guess!) but 80% accuracy may not be good enough if we have billions of events: 20% of billions is far too large a number to inspect these possible signals in any detail. In particle physics we shoot for a 5-sigma or greater evidence for discovery. That would mean our accuracy should only allow a 1 in 3.5 million error. We are far from that!
#
# The GBT model is a little better. We see this frequently: GBTs tend to be more powerful (but less explainable) than RF models. But we are still way off the requirements for a particle physics experiment

# %% [markdown]
# Produce a confusion matrix for each model and compare them

# %%
# I creaded this function (mostly copied from sklearn examples).
# You can use it to create the confusion matrix


def plot_confusion_matrix(y_true, y_pred,
                          normalize=False,
                          title='', labels=["P", "N"],
                          cmap=plt.cm.bone):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
          title = title + ' Normalized confusion matrix'
    else:
          title = title + ' Confusion matrix, without normalization'
    # Compute confusion matrix
    if normalize:
      cm = confusion_matrix(y_true, y_pred, normalize='all')
    else:
      cm = confusion_matrix(y_true, y_pred)
    # plot it
    fig, ax = plt.subplots(1, 1)
    fig.subplots_adjust()
    im = ax.imshow(np.rot90(cm), cmap=cmap)
    ax_divider = make_axes_locatable(ax)
    # add an axes to the right of the main axes.
    plt.xticks([0, 1], labels=labels[::-1])

    plt.text(0,1, f"{cm[0,0]:.2f}", ha='center', c="k" if cm[0,0] > 0.3 * cm.sum() else "w")
    plt.text(0,0, f"{cm[0,1]:.2f}", ha='center', c="k" if cm[0,1] > 0.3 * cm.sum() else "w")
    plt.text(1,1, f"{cm[1,0]:.2f}", ha='center', c="k" if cm[1,0] > 0.3 * cm.sum() else "w")
    plt.text(1,0, f"{cm[1,1]:.2f}", ha='center', c="k" if cm[1,1] > 0.3 * cm.sum() else "w")
    plt.ylim(-0.5,1.5)
    plt.yticks([0,1], labels=labels)
    plt.xlabel("prediction")
    plt.ylabel("truth")
    plt.title(title)
    cax = ax_divider.append_axes("right", size="10%", pad="2%")
    cb = plt.colorbar(im, cax=cax)

# %% [markdown]
# ## random forest prediction confusion matrix

# %%
plot_confusion_matrix(test_y, rf.predict(test_x), labels=["signal", "background"])
plot_confusion_matrix(test_y, rf.predict(test_x), labels=["signal", "background"], normalize=True)

# %% [markdown]
# ## gradient boosted tree prediction confusion matrix

# %%
plot_confusion_matrix(test_y, gbt.predict(test_x), labels=["signal", "background"])
plot_confusion_matrix(test_y, gbt.predict(test_x), labels=["signal", "background"], normalize=True)

# %% [markdown]
# Figure 6: confusion matrices for the random forest (two top plots) and gradient boosted tree model (bottom two) in natural units (top in each pair) and normalized (bottom). Since the target variable is roughly balance, the normalized and unnormalized matrices are very similar. False positives and false negatives are equivalently likely with the grandient boosted tree while the random forest is slightly biased and more likely to generate a type 2 error (false negative). In the context of a search for rare events this is highly undersirable!

# %% [markdown]
# Plot a simple ROC curve for the RF and GBT models  Describe it.

# %%
rf.predict_proba(test_x)[:,1]
# Out:
# Object `roc_curve` not found.
# array([0.45862232, 0.33642163, 0.25756664, ..., 0.23420109, 0.22739388,
#        0.51081692])

# %%
test_y.reshape(-1, 1).flatten()=="s"
# Out:
# array([ True,  True, False, ..., False, False,  True])

# %%
# The random forest model by itself
from sklearn.metrics import roc_curve
y_pred_grd_rfcat = rf.predict_proba(test_x)[:, 1]
y_pred_grd_gbtcat = gbt.predict_proba(test_x)[:, 1]

fpr_rf, tpr_rf, _ = roc_curve(test_y.reshape(-1, 1).flatten()=="s", y_pred_grd_rfcat)
fpr_gbt, tpr_gbt, _ = roc_curve(test_y.reshape(-1, 1).flatten()=="s", y_pred_grd_gbtcat)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_rf, tpr_rf, label='RF')
plt.plot(fpr_gbt, tpr_gbt, label='GBT')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Figure 7: the ROC represents the performance of the classifier at different detection thresholds. The GBT being above the RF throughout indicates that this method is more powerful at all thresholds

# %% [markdown]
# #Task 7 required for 661, EC for 461, tree-based regression
#
#
# - Use a Random Forest and a Gradiend Boosted Tree Regressor model to predict the weight of the particles. Compare the model performance on training and test setsm

# %%
rfR = RandomForestRegressor(max_depth=3, random_state=302)
rfR.fit(train_regress_x, train_regress_y)
gbtR = GradientBoostingRegressor(max_depth=3, random_state=302)
gbtR.fit(train_regress_x, train_regress_y)
# Out:
# GradientBoostingRegressor(random_state=302)

# %% [markdown]
#  Calculate the L2 and L1 loss functions for the fitted regression models (see slides for the definition) and discuss the results

# %%
def L1(truth, prediction):
  return np.sum(np.abs(truth - prediction)) / len(truth)

def L2(truth, prediction):
  return np.sum((truth - prediction)**2) / len(truth)

# %%
print(f"L1 RF {L1(test_regress_y,  rfR.predict(test_regress_x)):.2f}, L2 RF {L2(test_regress_y, rfR.predict(test_regress_x)):.2f}")
# Out:
# L1 RF 0.42, L2 RF 0.39

# %%
print(f"L1 GBT {L1(test_regress_y,  gbtR.predict(test_regress_x)):.2f}, L2 GBT {L2(test_regress_y, gbtR.predict(test_regress_x)):.2f}")
# Out:
# L1 GBT 0.35, L2 GBT 0.31

# %%
print(f"R2 for RF:{rfR.score(test_regress_x,  test_regress_y):.2f}, and GBT:{gbtR.score(test_regress_x,  test_regress_y):.2f}")
# Out:
# R2 for RF:0.29, and GBT:0.43

# %% [markdown]
# **Discuss!**

# %% [markdown]
# The task to predict the weight of a particle based on the interaction byproducts is performed with both RF and GBR. Both models can reproduce highly non linear interactions. The L1 error (mean average error) is smaller than the L2 error (mean square error) but comparable. This however has no significance: we are looking at different scales and since errors are <1 on average L2 will be smaller.
# To better interpret these number we need to know what they are as a percentage of the weight itself

# %%
print(f"mean and median values of variable weight: {np.mean(test_regress_y):.2},{np.median(test_regress_y):.2}")
# Out:
# mean and median values of variable weight: 0.44,0.064

# %% [markdown]
# indeed: the error is a large percentage of the mean value of the variable! this is _not_ a good model to predict the weight. The R2 value (returned by score) is showing this: a R2 of 0.29  indicates 0.29% of the variance is captured. The GBT does slightly better at 0.43, but this is not a highly performing model

# %% [markdown]
# #Task 8: Choose between feature importance and grid optimization (due for both 461 and 661)

# %% [markdown]
# # Task 8a: feature importance
# Use the "Titanic notebook" as a guide for the feature importance analysis  https://github.com/fedhere/DSPS_FBianco/blob/main/Labs/DSPS_2025_titanictree.ipynb
#
# - For the Random Forest classifier, find the 4 most important features based on the simple unoptimized model you created earlier on. Use the documentation to find out what they are. We have not talked abotu the physics of this problem at all but the Kaggle challenge description should provide enogh information for you to comment on this result is somewhat superficially.
#
# You can use ```rf.feature_importance_``` on the trained model to extract the relative importance of each feature (a number from 0 to 1) and then choose the features that have the 4 highest numbers (the numpy function ```argsort()``` is helpful here!)

# %%
fistd = np.std([tree.feature_importances_ for tree in rf.estimators_],
             axis=0)
print("Random Forest feature importance")
for f, fi, s in zip (higgsdata.drop(["EventId", "Label", "Weight"], axis=1).columns, rf.feature_importances_, fistd):
  print (f, fi.round(2), "+/-", s.round(2))
# Out:
# Random Forest feature importance
# DER_mass_MMC 0.3 +/- 0.28
# DER_mass_transverse_met_lep 0.05 +/- 0.08
# DER_mass_vis 0.09 +/- 0.13
# DER_pt_h 0.01 +/- 0.02
# DER_deltaeta_jet_jet 0.13 +/- 0.19
# DER_mass_jet_jet 0.07 +/- 0.15
# DER_prodeta_jet_jet 0.13 +/- 0.19
# DER_deltar_tau_lep 0.02 +/- 0.04
# DER_pt_tot 0.03 +/- 0.07
# DER_sum_pt 0.0 +/- 0.01
# DER_pt_ratio_lep_tau 0.01 +/- 0.03
# DER_met_phi_centrality 0.04 +/- 0.07
# DER_lep_eta_centrality 0.07 +/- 0.14
# PRI_tau_pt 0.01 +/- 0.03
# PRI_tau_eta 0.0 +/- 0.0
# PRI_tau_phi 0.0 +/- 0.0
# PRI_lep_pt 0.0 +/- 0.0
# PRI_lep_eta 0.0 +/- 0.01
# PRI_lep_phi 0.0 +/- 0.0
# PRI_met 0.01 +/- 0.02
# PRI_met_phi 0.0 +/- 0.0
# PRI_met_sumet 0.0 +/- 0.0
# PRI_jet_num 0.03 +/- 0.06
# PRI_jet_leading_pt 0.0 +/- 0.0
# PRI_jet_leading_eta 0.0 +/- 0.02
# PRI_jet_leading_phi 0.0 +/- 0.0
# PRI_jet_subleading_pt 0.0 +/- 0.01
# PRI_jet_subleading_eta 0.01 +/- 0.02
# PRI_jet_subleading_phi 0.0 +/- 0.0
# PRI_jet_all_pt 0.0 +/- 0.01

# %%
best_features_index = np.argsort(rf.feature_importances_)

# %%
higgsdata.drop(["EventId", "Label", "Weight"], axis=1).iloc[:, best_features_index[::-1]] #this sorts the data by feature
# Out:
#         DER_mass_MMC  DER_deltaeta_jet_jet  DER_prodeta_jet_jet  DER_mass_vis  \
# 0            138.470                 0.910                2.666        97.827
# 5             89.744                 2.636               -0.540        59.149
# 6            148.754                 0.733                0.113       107.782
# 11           114.744                 2.563               -1.401        75.712
# 23           141.481                 1.955               -0.923       111.581
# ...              ...                   ...                  ...           ...
# 249976       137.371                 3.189               -2.384        92.603
# 249980       119.934                 0.660                1.836        88.751
# 249985       126.151                 1.000               -0.240        95.258
# 249993       130.075                 0.936               -0.207        66.781
# 249994       217.020                 0.295               -0.014        62.824
#
# ...

# %%
plt.figure()
plt.title("Feature importances RF")
plt.barh(np.arange(rf.feature_importances_.shape[0]),
        rf.feature_importances_[best_features_index], xerr=fistd,
       align="center")
plt.yticks(range(rf.feature_importances_.shape[0]),
          labels=higgsdata.drop(["EventId", "Label", "Weight"], axis=1).columns[best_features_index])
plt.xlim(0, 1)
plt.show()

# %% [markdown]
# Figure 8: Importance of features in the RF prediction. The DER features are the only ones with notable significance and only 8 figures are significant overall. DER are derived features created from the raw (PRI) variables and they include domain knowledge. This confirms how the domain knowledge is critical in data science! Most of the prediction of the RF relies on the variable DER_mass_MMC

# %%
plt.figure()
plt.title("Feature importances GBT")
plt.barh(np.arange(gbt.feature_importances_.shape[0]),
        gbt.feature_importances_[best_features_index],
       align="center")
plt.yticks(range(gbt.feature_importances_.shape[0]),
          labels=higgsdata.drop(["EventId", "Label", "Weight"], axis=1).columns[best_features_index])
plt.xlim(0, 1)
plt.show()

# %% [markdown]
# Figure 9: importance of GBT ordered by the imporatance of the features in the RF model.
# The top features are teh same, with some notable reshuffling: the importance of DER_prodeta_jet_jet dropped below significance. The prediction relies even more significantly on DER_mass_MMC. It is common to see that the GBT would rely on features more unevenly than RF

# %% [markdown]
# # Task 8b: hyperparameters grid search
# - Explore the parameter space with the sklearn module ```sklearn.model_selection.RandomizedSearchCV``` *fitting only those 4 features*
#
# Follow this example to set up the parameter search. Set the estimators to 10 and 100, (the number of trees) and the max depth to 3, and 10, and None (let it be unconstrained). Set bootstrap to both True and False. Set the number of features to consider at every split to both "autp" and "sqrt". Use ```pprint``` like I did earlier in this notebook to print the parameters set
#
# **this takes some computational time! so do not start this at the last minute!!**

# %%
# choose your preferred values for the parameters you will test
random_grid = {
 'max_depth': [None, 10, 3],
 'max_features': ['sqrt', 'log2'],
 'n_estimators': [10,100, 500]}

# %%
random_grid = {'n_estimators': [10, 100],
               'max_depth': [3, 10, None],
               'bootstrap': [True, False],
               'max_features': ['sqrt', 'log2']}

# %%
pprint(random_grid)
# Out:
# {'bootstrap': [True, False],
#  'max_depth': [3, 10, None],
#  'max_features': ['sqrt', 'log2'],
#  'n_estimators': [10, 100]}

# %% [markdown]
#  mine and your best features do not necessarily have to be the same because our models may be different (different parameters, different random seed etc)

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
# Random search of parameters, using 3 fold cross validation,
# search across 18 different combinations
random_search = RandomizedSearchCV(estimator = rf, param_distributions=random_grid,
                                   n_iter=1, cv=3)

# %% [markdown]
# Note that this may take a long time! It took 1 hour for me to run this. Dont start at the last minute!!

# %%
random_search.fit(train_x[::5], train_y[::5])
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=RandomForestClassifier(max_depth=3,
#                                                     random_state=302),
#                    n_iter=1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [3, 10, None],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'n_estimators': [10, 100]})

# %%
random_search.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=3, max_features='log2',
#                        random_state=302)

# %%
for k in random_search.best_params_:
  print(k,random_search.best_params_[k])
# Out:
# n_estimators 100
# max_features log2
# max_depth 3
# bootstrap False

# %%
rf = RandomForestClassifier(max_features="autp")
pprint(rf.get_params())
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'autp',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
rf = RandomForestClassifier(**random_search.best_params_)
pprint(rf.get_params())
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 3,
#  'max_features': 'log2',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
rf.fit(train_x, train_y)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=3, max_features='log2')

# %%
print("Tuned RF  Parameters: {}".format(random_search.best_params_))
print("Best score is {}".format(rf.score(test_x, test_y)))
# Out:
# Tuned RF  Parameters: {'n_estimators': 100, 'max_features': 'log2', 'max_depth': 3, 'bootstrap': False}
# Best score is 0.7900052851018851

# %%
df = pd.DataFrame(random_search.cv_results_) # this shows the result for the given parameters

# %%
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       1.840833      0.229958         0.029896        0.003968
#
#    param_n_estimators param_max_features  param_max_depth  param_bootstrap  \
# 0                 100               log2                3            False
#
#                                               params  split0_test_score  \
# 0  {'n_estimators': 100, 'max_features': 'log2', ...           0.755725
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.756019           0.767107         0.759617        0.005298
#
#    rank_test_score
# 0                1

# %% [markdown]
# Plot a simple  ROC curve for the RF model with the best parameters found in the previous step. Describe it.

# %%
# The random forest model by itself
y_pred_grd_rfcat = rf.predict_proba(test_x)[:, 1]
y_pred_grd_gbtcat = gbt.predict_proba(test_x)[:, 1]

fpr_rf, tpr_rf, _ = roc_curve(test_y.reshape(-1, 1).flatten()=="s", y_pred_grd_rfcat)
fpr_gbt, tpr_gbt, _ = roc_curve(test_y.reshape(-1, 1).flatten()=="s", y_pred_grd_gbtcat)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_rf, tpr_rf, label='RF')
plt.plot(fpr_gbt, tpr_gbt, label='GBT')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
